# %%
import pandas as pd
print("In args.sml, computing Salas-Molina et al. method")
file_path = '/home/ia23938/Documents/GitHub/ValueSystemsAggregation/data/ess_example_data/single_example_results/single_example/means_and_salas_molina_ps/principles_for_slm.csv'
try:
    df = pd.read_csv(file_path)
    if df.empty:
        print(f"Warning: {file_path} is empty.")
except pd.errors.EmptyDataError:
    print(f"Error: {file_path} is empty or not a valid CSV.")
except Exception as e:
    print(f"Error reading {file_path}: {e}")
for series_name, series in df.items():
       print(series_name)
       print(series)
# Out:
# In args.sml, computing Salas-Molina et al. method
# 15-01-2025-extreme-util-principles.csv
# 0     2.1
# 1     2.3
# 2     2.2
# 3     2.1
# 4     2.3
# 5     2.1
# 6     2.5
# 7     2.5
# 8     2.0
# 9     2.3
# 10    2.3
# 11    2.3
# 12    2.3
# 13    2.3
# 14    1.9
# 15    2.3
# 16    1.9
# 17    2.3
# 18    2.0
# 19    2.5
# 20    1.9
# 21    2.3
# 22    1.9
# Name: 15-01-2025-extreme-util-principles.csv, dtype: float64
# 13-01-2025-against-principles.csv
# 0     8.0
# 1     2.0
# 2     7.3
# 3     9.6
# 4     5.9
# 5     7.3
# 6     9.2
# 7     2.4
# 8     4.3
# 9     4.4
# 10    2.2
# 11    2.0
# 12    2.0
# 13    9.6
# 14    2.1
# 15    2.3
# 16    5.8
# 17    8.3
# 18    2.0
# 19    2.3
# 20    2.3
# 21    8.6
# 22    2.1
# Name: 13-01-2025-against-principles.csv, dtype: float64
# 15-01-2025-50-pc-support-principles.csv
# 0      2.2
# 1      9.9
# 2      2.2
# 3      1.9
# 4      2.2
# 5      2.1
# 6      1.9
# 7      9.9
# 8      2.0
# 9      2.0
# 10     9.7
# 11     6.3
# 12     7.7
# 13     1.9
# 14     8.0
# 15    10.0
# 16     2.2
# 17     2.1
# 18     9.9
# 19     8.5
# 20     8.7
# 21     2.0
# 22     9.3
# Name: 15-01-2025-50-pc-support-principles.csv, dtype: float64
# 15-01-2025-general-opposition-principles.csv
# 0     7.5
# 1     2.3
# 2     8.5
# 3     6.9
# 4     8.5
# 5     6.3
# 6     6.3
# 7     2.4
# 8     9.1
# 9     7.8
# 10    2.3
# 11    2.4
# 12    2.1
# 13    9.6
# 14    1.9
# 15    2.3
# 16    6.1
# 17    6.5
# 18    1.9
# 19    2.1
# 20    2.3
# 21    7.2
# 22    2.4
# Name: 15-01-2025-general-opposition-principles.csv, dtype: float64
# 15-01-2025-general-support-principles.csv
# 0     2.3
# 1     8.0
# 2     1.9
# 3     2.0
# 4     2.2
# 5     1.9
# 6     1.9
# 7     9.0
# 8     2.2
# 9     2.0
# 10    6.8
# 11    5.3
# 12    5.9
# 13    2.3
# 14    7.1
# 15    9.3
# 16    1.9
# 17    2.1
# 18    8.4
# 19    8.6
# 20    5.4
# 21    2.2
# 22    6.3
# Name: 15-01-2025-general-support-principles.csv, dtype: float64
# 15-01-2025-bottom-quartile-principles.csv
# 0     2.5
# 1     3.3
# 2     2.5
# 3     2.4
# 4     2.4
# 5     2.5
# 6     2.4
# 7     4.0
# 8     2.4
# 9     2.4
# 10    3.6
# 11    3.4
# 12    3.2
# 13    2.4
# 14    3.4
# 15    3.8
# 16    2.4
# 17    2.4
# 18    2.9
# 19    4.4
# 20    4.2
# 21    2.5
# 22    3.6
# Name: 15-01-2025-bottom-quartile-principles.csv, dtype: float64
# 12-01-2025-principles.csv
# 0     4.4
# 1     2.2
# 2     4.9
# 3     6.6
# 4     6.3
# 5     6.5
# 6     4.7
# 7     2.1
# 8     2.8
# 9     5.1
# 10    2.3
# 11    1.9
# 12    2.2
# 13    9.9
# 14    1.9
# 15    2.3
# 16    2.9
# 17    6.8
# 18    2.0
# 19    2.1
# 20    2.0
# 21    3.8
# 22    2.1
# Name: 12-01-2025-principles.csv, dtype: float64
# 15-01-2025-extreme-egal-principles.csv
# 0     9.3
# 1     7.7
# 2     5.8
# 3     8.7
# 4     8.8
# 5     3.8
# 6     8.5
# 7     6.0
# 8     3.3
# 9     3.2
# 10    8.1
# 11    7.0
# 12    7.5
# 13    3.5
# 14    5.7
# 15    2.8
# 16    5.3
# 17    9.6
# 18    5.4
# 19    7.7
# 20    9.6
# 21    7.2
# 22    4.2
# Name: 15-01-2025-extreme-egal-principles.csv, dtype: float64
# 15-01-2025-50-pc-opposition-principles.csv
# 0     6.3
# 1     1.9
# 2     6.8
# 3     7.3
# 4     9.5
# 5     7.6
# 6     9.0
# 7     2.0
# 8     8.5
# 9     7.3
# 10    2.2
# 11    1.9
# 12    2.1
# 13    7.2
# 14    1.9
# 15    2.2
# 16    7.3
# 17    7.1
# 18    1.9
# 19    2.0
# 20    1.9
# 21    8.9
# 22    1.9
# Name: 15-01-2025-50-pc-opposition-principles.csv, dtype: float64
# 15-01-2025-top-quartile-principles.csv
# 0     2.0
# 1     9.3
# 2     1.9
# 3     1.9
# 4     1.9
# 5     2.0
# 6     2.0
# 7     8.6
# 8     2.0
# 9     1.9
# 10    9.4
# 11    9.5
# 12    9.1
# 13    1.9
# 14    9.0
# 15    9.6
# 16    1.9
# 17    1.9
# 18    8.7
# 19    8.9
# 20    9.2
# 21    1.9
# 22    8.7
# Name: 15-01-2025-top-quartile-principles.csv, dtype: float64
# 16-01-2025-ESS-principles.csv
# 0     8.9
# 1     8.3
# 2     8.3
# 3     6.1
# 4     8.1
# 5     7.9
# 6     9.1
# 7     8.6
# 8     7.8
# 9     7.4
# 10    8.3
# 11    8.4
# 12    8.4
# 13    9.0
# 14    8.8
# 15    9.5
# 16    7.4
# 17    8.1
# 18    8.1
# 19    9.1
# 20    8.3
# 21    8.3
# 22    8.4
# Name: 16-01-2025-ESS-principles.csv, dtype: float64
