# %% [markdown]
# # Distribution Checker
# This file picks out a random .csv from each society folder, and its distribtion is checked and printed
#
# Columns in each society csv are the following: ,agent_id,pp_1,pp_1_1,pp_2,pp_2_1,pp_3,pp_3_1,P_1,P_1_1,P_2,P_2_1,P_3,P_3_1,a_enjoy_camp,a_enjoy_resort,a_budget_camp,a_budget_resort,a_conform_chain,a_conform_independent,a_stim_chain,a_stim_independent,a_enjoy_classic,a_enjoy_unknown,a_stimulation_classic,a_stimulation_unknown

# %%
import pandas as pd
import matplotlib.pyplot as plt
import random


society_num = random.randint(1,100) 
util_file = pd.read_csv('/home/ia23938/Documents/GitHub/ValueSystemsAggregation/data/society_data/util_societies/util_society_'+str(society_num)+'.csv')

util_file.describe()
# Out:
#        Unnamed: 0    agent_id        pp_1      pp_1_1        pp_2      pp_2_1  \
# count  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# mean    49.500000   49.500000    0.188206    0.811794    0.490141    0.509859
# std     29.011492   29.011492    0.096723    0.096723    0.082583    0.082583
# min      0.000000    0.000000    0.000000    0.613454    0.286820    0.296436
# 25%     24.750000   24.750000    0.138982    0.741663    0.436216    0.457535
# 50%     49.500000   49.500000    0.199978    0.800022    0.495035    0.504965
# 75%     74.250000   74.250000    0.258337    0.861018    0.542465    0.563784
# max     99.000000   99.000000    0.386546    1.000000    0.703564    0.713180
#
#              pp_3      pp_3_1         P_1       P_1_1  ...  a_budget_camp  \
# count  100.000000  100.000000  100.000000  100.000000  ...     100.000000
# mean     0.501366    0.498634    0.499445    0.500555  ...      -0.050244
# std      0.100108    0.100108    0.098120    0.098120  ...       0.523407
# min      0.263045    0.288193    0.213258    0.233239  ...      -1.000000
# 25%      0.438679    0.416678    0.431427    0.425990  ...      -0.468002
# 50%      0.501727    0.498273    0.496116    0.503884  ...       0.012532
# 75%      0.583322    0.561321    0.574010    0.568573  ...       0.330555
# max      0.711807    0.736955    0.766761    0.786742  ...       1.000000
#
#        a_budget_resort  a_conform_chain  a_conform_independent  a_stim_chain  \
# count       100.000000       100.000000             100.000000    100.000000
# mean         -0.004567        -0.015106               0.000119      0.028215
# std           0.451847         0.498227               0.475860      0.477588
# min          -0.993965        -1.000000              -1.000000     -1.000000
# 25%          -0.343476        -0.407036              -0.325839     -0.275973
# 50%           0.018722         0.005739              -0.028806     -0.007511
# 75%           0.304919         0.331457               0.342667      0.362238
# max           1.000000         1.000000               1.000000      1.000000
#
#        a_stim_independent  a_enjoy_classic  a_enjoy_unknown  \
# count          100.000000       100.000000       100.000000
# mean             0.001592         0.100133        -0.020963
# std              0.486396         0.459311         0.466676
# min             -1.000000        -1.000000        -1.000000
# 25%             -0.336568        -0.185961        -0.404253
# 50%             -0.014355         0.113350         0.003251
# 75%              0.301034         0.415232         0.295372
# max              1.000000         1.000000         1.000000
#
#        a_stimulation_classic  a_stimulation_unknown
# count             100.000000             100.000000
# mean                0.039449              -0.030053
# std                 0.501399               0.484488
# min                -1.000000              -1.000000
# 25%                -0.327736              -0.376144
# 50%                 0.037481              -0.069731
# 75%                 0.380485               0.367499
# max                 1.000000               1.000000
#
# [8 rows x 26 columns]

# %%
col = "pp_2"

util_file[col].hist()
# add labels and title
plt.xlabel('value')
plt.ylabel('Frequency')
plt.title('Distribution of '+col)
# Out:
# Text(0.5, 1.0, 'Distribution of pp_2')

# %% [markdown]
# ## Checking for minority groups
# The following code will look at all of each society's data and find what constitutes a minority group for each principle value

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import random


# Path to the folder containing the CSV files
folder_path = '/home/ia23938/Documents/GitHub/ValueSystemsAggregation/data/society_data/norm_societies/'

# List to hold dataframes
dfs = []

# Load all CSV files into dataframes and append to the list
for filename in os.listdir(folder_path):
    if filename.endswith('.csv'):
        df = pd.read_csv(os.path.join(folder_path, filename))
        dfs.append(df)

# Concatenate all dataframes
all_data = pd.concat(dfs)

# Calculate the average for every column
average_data = all_data.mean()

average_data_df = average_data.to_frame().T
print(average_data_df)
# Out:
#    Unnamed: 0  agent_id      pp_1    pp_1_1      pp_2    pp_2_1      pp_3  \
# 0        49.5      49.5  0.499238  0.500762  0.498736  0.501264  0.498984
#
#      pp_3_1       P_1     P_1_1  ...  a_budget_camp  a_budget_resort  \
# 0  0.501016  0.501335  0.498665  ...       0.006031         0.001727
#
#    a_conform_chain  a_conform_independent  a_stim_chain  a_stim_independent  \
# 0        -0.000764               0.004273       0.00152           -0.006616
#
#    a_enjoy_classic  a_enjoy_unknown  a_stimulation_classic  \
# 0         0.010486        -0.007088               0.003219
#
#    a_stimulation_unknown
# 0               0.006985
#
# [1 rows x 26 columns]

# %%
col = "pp_2"

all_data[col].hist()
# add labels and title
plt.xlabel('value')
plt.ylabel('Frequency')
plt.title('Distribution of '+col)
# Out:
# Text(0.5, 1.0, 'Distribution of pp_2')

# %%
society_nums = [69, 39, 57, 42, 25, 85, 74, 84, 16, 21]

society_nums = list(range(1, 99))
# Path to the folder containing the CSV files
folder_path = '/home/ia23938/Documents/GitHub/ValueSystemsAggregation/data/society_data/norm_societies/'

dfs = []

for society_num in society_nums:
    df = pd.read_csv(os.path.join(folder_path, 'norm_society_'+str(society_num)+'.csv'))
    dfs.append(df)


# Concatenate all dataframes
all_data = pd.concat(dfs)

# Create a list of dataframes where each dataframe contains all rows for a unique agent_id
unique_agent_dfs = [all_data[all_data['agent_id'] == agent_id] for agent_id in all_data['agent_id'].unique()]

# Calculate the mean and standard deviation for all_data
mean_all_data = all_data.mean()
std_all_data = all_data.std()

unique_agent_dfs[0]
# Out:
#     Unnamed: 0  agent_id      pp_1    pp_1_1      pp_2    pp_2_1      pp_3  \
# 0            0       0.0  0.337037  0.662963  0.369478  0.630522  0.544223
# 0            0       0.0  0.403896  0.596104  0.426684  0.573316  0.436655
# 0            0       0.0  0.572267  0.427733  0.498430  0.501570  0.447890
# 0            0       0.0  0.499163  0.500837  0.425003  0.574997  0.382676
# 0            0       0.0  0.611835  0.388165  0.536653  0.463347  0.557540
# ..         ...       ...       ...       ...       ...       ...       ...
# 0            0       0.0  0.528883  0.471117  0.498214  0.501786  0.369869
# 0            0       0.0  0.698269  0.301731  0.383667  0.616333  0.459059
# 0            0       0.0  0.394123  0.605877  0.345369  0.654631  0.506271
# 0            0       0.0  0.568836  0.431164  0.461172  0.538828  0.498301
# 0            0       0.0  0.482807  0.517193  0.496343  0.503657  0.508806
#
#       pp_3_1       P_1     P_1_1  ...  a_budget_camp  a_budget_resort  \
# 0   0.455777  0.562884  0.437116  ...       0.669224        -0.273252
# 0   0.563345  0.513785  0.486215  ...       0.394516         0.408062
# 0   0.552110  0.392565  0.607435  ...       0.000919         0.340109
# 0   0.617324  0.537329  0.462671  ...       0.261598         0.082265
# 0   0.442460  0.454705  0.545295  ...       0.654442         0.335127
# ..       ...       ...       ...  ...            ...              ...
# 0   0.630131  0.655664  0.344336  ...       0.011542        -0.272610
# 0   0.540941  0.596458  0.403542  ...      -0.088118         0.294497
# 0   0.493729  0.735655  0.264345  ...       0.005073         1.000000
# 0   0.501699  0.420126  0.579874  ...      -0.341646         0.068416
# 0   0.491194  0.452543  0.547457  ...      -0.139285         0.121123
#
#     a_conform_chain  a_conform_independent  a_stim_chain  a_stim_independent  \
# 0          0.602485              -0.688983      0.291435            0.145572
# 0         -0.008962              -0.983119     -0.672074           -0.253838
# 0         -0.508856               0.895185     -1.000000            0.098512
# 0         -0.216675               0.507648     -0.299740           -0.329020
# 0         -0.064067              -0.774078      0.435220            0.370314
# ..              ...                    ...           ...                 ...
# 0          0.286812              -0.023387      0.920605           -0.161902
# 0          0.772683              -0.483787      0.472108           -0.213017
# 0         -0.125302               0.536897      0.289855           -0.040236
# 0         -0.119693               0.293081      0.230138           -0.220951
# 0         -0.068696               0.238456     -0.278415           -0.391158
#
#     a_enjoy_classic  a_enjoy_unknown  a_stimulation_classic  \
# 0         -0.722193         0.495182               0.667907
# 0         -0.435511        -0.056652              -0.249383
# 0          0.341951        -0.679152              -0.200544
# 0         -0.485357        -0.212630              -0.203823
# 0          0.138495        -0.661700              -0.970503
# ..              ...              ...                    ...
# 0          0.572802         0.092620              -0.593346
# 0          0.009347         0.012689               0.851072
# 0         -0.274143         0.336297               0.910580
# 0         -0.498649        -0.121461               0.221534
# 0         -0.609364         0.451370               0.436022
#
#     a_stimulation_unknown
# 0                0.961038
# 0               -0.101031
# 0               -0.348654
# 0               -0.043437
# 0               -0.574721
# ..                    ...
# 0               -0.255576
# 0               -0.328202
# 0                0.013674
# 0               -0.212998
# 0               -1.000000
#
# [98 rows x 26 columns]

# %%
for df in unique_agent_dfs:
    agent_data = df.set_index('agent_id')
    # Identify columns where agent_data is significantly different from all_data
    significant_columns = []
    for col in agent_data.columns:
        for row in agent_data[col]:
            if abs(row - mean_all_data[col]) > 2 * std_all_data[col]:
                print('row is: ', row)
                print('mean is: ', mean_all_data[col])
                print("found a significant row")
        if abs(agent_data[col].mean() - mean_all_data[col]) > 2 * std_all_data[col]:
            significant_columns.append(col)

    # Plot histograms for significant columns
    if significant_columns:
        agent_data[significant_columns].hist(figsize=(1.5, 1.5))
        plt.xlim(-1, 1)
        plt.show()
        print("FOUND! Agent number: ", df['agent_id'].iloc[0])
    #else:
# Out:
# row is:  0.2587984010876986
# mean is:  0.4994661633593985
# found a significant row
# row is:  0.2906720293955408
# mean is:  0.4994661633593985
# found a significant row
# row is:  0.706703665232463
# mean is:  0.4994661633593985
# found a significant row
# row is:  0.7412015989123013
# mean is:  0.5005338366406016
# found a significant row
# row is:  0.7093279706044592
# mean is:  0.5005338366406016
# found a significant row
# row is:  0.293296334767537
# mean is:  0.5005338366406016
# found a significant row
# row is:  0.2516654339289986
# mean is:  0.49878109736667264
# found a significant row
# row is:  0.7600075081947463
# mean is:  0.49878109736667264
# found a significant row
# row is:  0.7483345660710014
# mean is:  0.5012189026333271
# found a significant row
# row is:  0.2399924918052537
# mean is:  0.5012189026333271
# found a significant row
# row is:  0.2815341656623406
# mean is:  0.4991048288398132
# found a significant row
# row is:  0.2616554055973592
# mean is:  0.4991048288398132
# found a significant row
# row is:  0.2147287880573117
# mean is:  0.4991048288398132
# found a significant row
# row is:  0.2309361413908913
# mean is:  0.4991048288398132
# found a significant row
# row is:  0.7184658343376593
# mean is:  0.5008951711601867
# found a significant row
# row is:  0.
# found a significant row
# row is:  1.0
# mean is:  0.001814056422023334
# found a significant row
# row is:  -0.9648872331788136
# mean is:  0.001814056422023334
# found a significant row
# row is:  0.9801973642649175
# mean is:  0.001814056422023334
# found a significant row
# row is:  1.0
# mean is:  0.001814056422023334
# found a significant row
# row is:  0.98643346586875
# mean is:  0.001814056422023334
# found a significant row
# row is:  1.0
# mean is:  0.001814056422023334
# found a significant row
# row is:  -1.0
# mean is:  0.001814056422023334
# found a significant row
# row is:  1.0
# mean is:  0.001814056422023334
# found a significant row
# row is:  -1.0
# mean is:  -0.0034332642879093146
# found a significant row
# row is:  1.0
# mean is:  -0.0034332642879093146
# found a significant row
# row is:  1.0
# mean is:  -0.0034332642879093146
# found a significant row
# row is:  -1.0
# mean is:  -0.0034332642879093146
# found a significant row
# row is:  -1.0
# mean is:  0.005250236779231553
# found a significant row
# row is:  1.0
# mean is:  0.005250236779231553
# found a significant row
# row is:  1.0
# mean is:  0.005250236779231553
# found a significant row
# row is:  1.0
# mean is:  0.005250236779231553
# found a significant row
# row is:  1.0
# mean is:  0.0011033902261074543
# found a significant row
# row is:  0.9809211267916328
# mean is:  0.0011033902261074543
# found a significant row
# row is:  -1.0
# mean is:  0.0011033902261074543
# found a significant row
# row is:  -1.0
# mean is:  0.0011033902261074543
# found a significant row
# row is:  1.0
# mean is:  0.0011033902261074543
# found a significant row
# row is:  -1.0
# mean is:  0.0011033902261074543
# found a significant row
# row is:  1.0
# mean is:  -0.0011875702177889193
# found a significant row
# row is:  -0.9762878450310368
# mean is:  -0.0011875702177889193
# found a significant row
# row is:  -1.0
# mean is:  -0.0011875702177889193
# found a significant row
# row is:  -1.0
# mean is:  -0.0011875702177889193
# found a significant row
# row is:  1.0
# mean is:  -0.0011875702177889193
# found a significant row
# row is:  0.9733658784960032
# mean is:  -0.0011875702177889193
# found a significant row
# row is:  1.0
# mean is:  -0.0011875702177889193
# found a significant row
# row is:  -1.0
# mean is:  0.004826638047147292
# found a significant row
# row is:  -1.0
# mean is:  0.004826638047147292
# found a significant row
# row is:  -0.9871706720695914
# mean is:  0.004826638047147292
# found a significant row
# row is:  0.9865628793247242
# mean is:  0.004826638047147292
# found a significant row
# row is:  1.0
# mean is:  0.004826638047147292
# found a significant row
# row is:  1.0
# mean is:  0.004826638047147292
# found a significant row
# row is:  1.0
# mean is:  0.004826638047147292
# found a significant row
# row is:  1.0
# mean is:  0.0019310000059200637
# found a significant row
# row is:  -1.0
# mean is:  0.0019310000059200637
# found a significant row
# row is:  -1.0
# mean is:  0.0019310000059200637
# found a significant row
# row is:  -1.0
# mean is:  -0.006813937681312025
# found a significant row
# row is:  0.9603169091649518
# mean is:  -0.006813937681312025
# found a significant row
# row is:  -1.0
# mean is:  -0.006813937681312025
# found a significant row
# row is:  -1.0
# mean is:  0.010616367768230463
# found a significant row
# row is:  1.0
# mean is:  0.010616367768230463
# found a significant row
# row is:  -1.0
# mean is:  0.010616367768230463
# found a significant row
# row is:  0.9710422175290956
# mean is:  0.010616367768230463
# found a significant row
# row is:  -1.0
# mean is:  0.010616367768230463
# found a significant row
# row is:  1.0
# mean is:  -0.007596775400581668
# found a significant row
# row is:  1.0
# mean is:  -0.007596775400581668
# found a significant row
# row is:  -1.0
# mean is:  -0.007596775400581668
# found a significant row
# row is:  1.0
# mean is:  -0.007596775400581668
# found a significant row
# row is:  -1.0
# mean is:  -0.007596775400581668
# found a significant row
# row is:  -0.982352961334106
# mean is:  -0.007596775400581668
# found a significant row
# row is:  1.0
# mean is:  0.003921960295649601
# found a significant row
# row is:  -1.0
# mean is:  0.003921960295649601
# found a significant row
# row is:  -1.0
# mean is:  0.003921960295649601
# found a significant row
# row is:  -0.9812119568775008
# mean is:  0.003921960295649601
# found a significant row
# row is:  1.0
# mean is:  0.007012624965220053
# found a significant row
# row is:  -1.0
# mean is:  0.007012624965220053
# found a significant row
# row is:  1.0
# mean is:  0.007012624965220053
# found a significant row
# row is:  1.0
# mean is:  0.007012624965220053
# found a significant row
# row is:  -1.0
# mean is:  0.007012624965220053
# found a significant row
# row is:  1.0
# mean is:  0.007012624965220053
# found a significant row
# FOUND! Agent number:  4.0
# row is:  0.2785391539086495
# mean is:  0.4994661633593985
# found a significant row
# row is:  0.224666730153043
# mean is:  0.4994661633593985
# found a significant row
# row is:  0.7058852289960129
# mean is:  0.4994661633593985
# found a significant row
# row is:  0.7214608460913505
# mean is:  0.5005338366406016
# found a significant row
# row is:  0.7753332698469569
# mean is:  0.5005338366406016
# found a significant row
# row is:  0.2941147710039871
# mean is:  0.5005338366406016
# found a significant row
# row is:  0.7363400148520037
# mean is:  0.49878109736667264
# found a significant row
# row is:  0.2939683976509816
# mean is:  0.49878109736667264
# found a significant row
# row is:  0.2811628089626536
# mean is:  0.49878109736667264
# found a significant row
# row is:  0.7228269204962322
# mean is:  0.49878109736667264
# found a significant row
# row is:  0.2759252640616429
# mean is:  0.49878109736667264
# found a significant row
# row is:  0.2636599851479962
# mean is:  0.5012189026333271
# found a significant row
# row is:  0.7060316023490184
# mean is:  0.5012189026333271
# found a significant row
# row is:  0.7188371910373463
# mean is:  0.5012189026333271
# found a significant row
# row is:  0.2771730795037678
# mean is:  0.5012189026333271
# found a significant row
# row is:  0.724074735938357
# mean is:  0.5012189026333271
# found a significant row
# row is:  0.2671297084238418
# mean is:  0.4991048288398132
# found a significant row
# row is:  0.2625659899836307
# mean is:  0.4991048288398132
# found a significant row
# row is:  0.2648516677284626
# mean is:  0.4991048288398132
# found a significant row
# row is:  0.7328702915761581
# mean is:  0.5008951711601867
# found a significant row
# row is:  0.7374340100163693
# mean is:  0.5008951711601867
# found a significant row
# row is:  0.7351483322715374
# mean is:  0.5008951711601867
# found a significant row
# row is:  0.2770377982962411
# mean is:  0.501354806964405
# found a significant row
# row is:  0.2397131284399472
# mean is:  0.501354806964405
# found a significant row
# row is:  0.7210461648337867
# mean is:  0.501354806964405
# found a significant row
# row is:  0.779295404652492
# mean is:  0.501354806964405
# found a significant row
# row is:  0.2209642799260191
# mean is:  0.501354806964405
# found a significant row
# row is:  0.7141280554640862
# mean is:  0.501354806964405
# found a significant row
# row is:  0.7241178619576344
# mean is:  0.501354806964405
# found a significant row
# row is:  0.2383939304164877
# mean is:  0.501354806964405
# found a significant row
# row is:  0.7229622017037589
# mean is:  0.4986451930355949
# found a significant row
# row is:  0.7602868715600528
# mean is:  0.4986451930355949
# found a significant row
# row is:  0.2789538351662133
# mean is:  0.4986451930355949
# found a significant row
# row is:  0.2207045953475079
# mean is:  0.4986451930355949
# found a significant row
# row is:  0.7790357200739808
# mean is:  0.4986451930355949
# found a significant row
# row is:  0.2858719445359138
# mean is:  0.4986451930355949
# found a significant row
# row is:  0.2758821380423656
# mean is:  0.4986451930355949
# found a significant row
# row is:  0.7616060695835123
# mean is:  0.4986451930355949
# found a significant row
# row is:  0.2939305410173871
# mean is:  0.5010289604476129
# found a significant row
# row is:  0.703536078236184
# mean is:  0.5010289604476129
# found a significant row
# row is:  0.7516328429921975
# mean is:  0.5010289604476129
# found a significant row
# row is:  0.7060694589826129
# mean is:  0.49897103955238703
# found a significant row
# row is:  0.296463921763816
# mean is:  0.49897103955238703
# found a significant row
# row is:  0.2483671570078025
# mean is:  0.49897103955238703
# found a significant row
# row is:  0.2552392671411416
# mean is:  0.5011102957672127
# found a significant row
# row is:  0.2702571245582329
# mean is:  0.5011102957672127
# found a significant row
# row is:  0.7447607328588584
# mean is:  0.4988897042327872
# found a significant row
# row is:  0.7297428754417671
# mean is:  0.4988897042327872
# found a significant row
# row is:  -0.9890329899269212
# mean is:  0.001814056422023334
# found a significant row
# row is:  0.9990537145684092
# mean is:  0.001814056422023334
# found a significant row
# row is:  0.9638399064770464
# mean is:  0.001814056422023334
# found a significant row
# row is:  1.0
# mean is:  -0.0034332642879093146
# found a significant row
# row is:  1.0
# mean is:  -0.0034332642879093146
# found a significant row
# row is:  -1.0
# mean is:  -0.0034332642879093146
# found a significant row
# row is:  1.0
# mean is:  -0.0034332642879093146
# found a significant row
# row is:  1.0
# mean is:  -0.0034332642879093146
# found a significant row
# row is:  -1.0
# mean is:  0.005250236779231553
# found a significant row
# row is:  -1.0
# mean is:  0.005250236779231553
# found a significant row
# row is:  -1.0
# mean is:  0.005250236779231553
# found a significant row
# row is:  1.0
# mean is:  0.005250236779231553
# found a significant row
# row is:  1.0
# mean is:  0.0011033902261074543
# found a significant row
# row is:  1.0
# mean is:  0.0011033902261074543
# found a significant row
# row is:  1.0
# mean is:  0.0011033902261074543
# found a significant row
# row is:  -1.0
# mean is:  0.0011033902261074543
# found a significant row
# row is:  -0.9736556972440492
# mean is:  0.0011033902261074543
# found a significant row
# row is:  -1.0
# mean is:  0.0011033902261074543
# found a significant row
# row is:  -0.9991801117925526
# mean is:  0.0011033902261074543
# found a significant row
# row is:  1.0
# mean is:  -0.0011875702177889193
# found a significant row
# row is:  1.0
# mean is:  -0.0011875702177889193
# found a significant row
# row is:  0.9800746110300124
# mean is:  -0.0011875702177889193
# found a significant row
# row is:  1.0
# mean is:  0.004826638047147292
# found a significant row
# row is:  1.0
# mean is:  0.004826638047147292
# found a significant row
# row is:  1.0
# mean is:  0.004826638047147292
# found a significant row
# row is:  -1.0
# mean is:  0.004826638047147292
# found a significant row
# row is:  -1.0
# mean is:  0.0019310000059200637
# found a significant row
# row is:  1.0
# mean is:  0.0019310000059200637
# found a significant row
# row is:  -1.0
# mean is:  0.0019310000059200637
# found a significant row
# row is:  0.990824289854061
# mean is:  -0.006813937681312025
# found a significant row
# row is:  -1.0
# mean is:  -0.006813937681312025
# found a significant row
# row is:  1.0
# mean is:  -0.006813937681312025
# found a significant row
# row is:  0.9767230365434598
# mean is:  -0.006813937681312025
# found a significant row
# row is:  -1.0
# mean is:  -0.006813937681312025
# found a significant row
# row is:  1.0
# mean is:  -0.006813937681312025
# found a significant row
# row is:  -1.0
# mean is:  -0.006813937681312025
# found a significant row
# row is:  -1.0
# mean is:  -0.006813937681312025
# found a significant row
# row is:  -1.0
# mean is:  -0.006813937681312025
# found a significant row
# row is:  1.0
# mean is:  -0.006813937681312025
# found a significant row
# row is:  0.9947962247427772
# mean is:  -0.006813937681312025
# found a significant row
# row is:  1.0
# mean is:  -0.006813937681312025
# found a significant row
# row is:  -0.974561303324796
# mean is:  0.010616367768230463
# found a significant row
# row is:  0.994696871278402
# mean is:  0.010616367768230463
# found a significant row
# row is:  -0.9874288496246358
# mean is:  0.010616367768230463
# found a significant row
# row is:  1.0
# mean is:  0.010616367768230463
# found a significant row
# row is:  1.0
# mean is:  0.010616367768230463
# found a significant row
# row is:  1.0
# mean is:  0.010616367768230463
# found a significant row
# row is:  1.0
# mean is:  -0.007596775400581668
# found a significant row
# row is:  1.0
# mean is:  -0.007596775400581668
# found a significant row
# row is:  1.0
# mean is:  -0.007596775400581668
# found a significant row
# row is:  -0.9784862157749749
# mean is:  -0.007596775400581668
# found a significant row
# row is:  -1.0
# mean is:  -0.007596775400581668
# found a significant row
# row is:  -0.9787959619805486
# mean is:  0.003921960295649601
# found a significant row
# row is:  1.0
# mean is:  0.003921960295649601
# found a significant row
# row is:  -1.0
# mean is:  0.003921960295649601
# found a significant row
# row is:  -0.9520236225879222
# mean is:  0.007012624965220053
# found a significant row
# row is:  1.0
# mean is:  0.007012624965220053
# found a significant row
# row is:  1.0
# mean is:  0.007012624965220053
# found a significant row
# row is:  0.9901683622288944
# mean is:  0.007012624965220053
# found a significant row
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 17
#      15 # Plot histograms for significant columns
#      16 if significant_columns:
# ---> 17     agent_data[significant_columns].hist(figsize=(1.5, 1.5))
#      18     plt.xlim(-1, 1)
#      19     plt.show()
#
# File ~/miniconda3/envs/value-agg/lib/python3.11/site-packages/pandas/plotting/_core.py:251, in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, backend, legend, **kwargs)
#     164 """
#     165 Make a histogram of the DataFrame's columns.
#     166
#    (...)
#     248     >>> hist = df.hist(bins=3)
#     249 """
#     250 plot_backend = _get_plot_backend(backend)
# --> 251 return plot_backend.hist_frame(
#     252     data,
#     253     column=column,
#     254     by=by,
#     255     grid=grid,
#     256     xlabelsize=xlabelsize,
#     257     xrot=xrot,
#     258     ylabelsize=ylabelsize,
#     259     yrot=yrot,
#     260     ax=ax,
#     261     sharex=sharex,
#     262     sharey=sharey,
#     263     figsize=figsize,
#     264     layout=layout,
#     265     legend=legend,
#     266     bins=bins,
#     267     **kwargs,
#     268 )
#
# File ~/miniconda3/envs/value-agg/lib/python3.11/site-packages/pandas/plotting/_matplotlib/hist.py:570, in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, legend, **kwds)
#     568 if legend and can_set_label:
#     569     kwds["label"] = col
# --> 570 ax.hist(data[col].dropna().values, bins=bins, **kwds)
#     571 ax.set_title(col)
#     572 ax.grid(grid)
#
# File ~/miniconda3/envs/value-agg/lib/python3.11/site-packages/matplotlib/__init__.py:1473, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1470 @functools.wraps(func)
#    1471 def inner(ax, *args, data=None, **kwargs):
#    1472     if data is None:
# -> 1473         return func(
#    1474             ax,
#    1475             *map(sanitize_sequence, args),
#    1476             **{k: sanitize_sequence(v) for k, v in kwargs.items()})
#    1478     bound = new_sig.bind(ax, *args, **kwargs)
#    1479     auto_label = (bound.arguments.get(label_namer)
#    1480                   or bound.kwargs.get(label_namer))
#
# File ~/miniconda3/envs/value-agg/lib/python3.11/site-packages/matplotlib/axes/_axes.py:7061, in Axes.hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    7059 else:
#    7060     height = top
# -> 7061 bars = _barfunc(bins[:-1]+boffset, height, width,
#    7062                 align='center', log=log,
#    7063                 color=color, **{bottom_kwarg: bottom})
#    7064 patches.append(bars)
#    7065 if stacked:
#
# File ~/miniconda3/envs/value-agg/lib/python3.11/site-packages/matplotlib/__init__.py:1473, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1470 @functools.wraps(func)
#    1471 def inner(ax, *args, data=None, **kwargs):
#    1472     if data is None:
# -> 1473         return func(
#    1474             ax,
#    1475             *map(sanitize_sequence, args),
#    1476             **{k: sanitize_sequence(v) for k, v in kwargs.items()})
#    1478     bound = new_sig.bind(ax, *args, **kwargs)
#    1479     auto_label = (bound.arguments.get(label_namer)
#    1480                   or bound.kwargs.get(label_namer))
#
# File ~/miniconda3/envs/value-agg/lib/python3.11/site-packages/matplotlib/axes/_axes.py:2597, in Axes.bar(self, x, height, width, bottom, align, **kwargs)
#    2595     else:  # horizontal
#    2596         r.sticky_edges.x.append(l)
# -> 2597     self.add_patch(r)
#    2598     patches.append(r)
#    2600 if xerr is not None or yerr is not None:
#
# File ~/miniconda3/envs/value-agg/lib/python3.11/site-packages/matplotlib/axes/_base.py:2385, in _AxesBase.add_patch(self, p)
#    2383 self._set_artist_props(p)
#    2384 if p.get_clip_path() is None:
# -> 2385     p.set_clip_path(self.patch)
#    2386 self._update_patch_limits(p)
#    2387 self._children.append(p)
#
# File ~/miniconda3/envs/value-agg/lib/python3.11/site-packages/matplotlib/artist.py:799, in Artist.set_clip_path(self, path, transform)
#     797 if transform is None:
#     798     if isinstance(path, Rectangle):
# --> 799         self.clipbox = TransformedBbox(Bbox.unit(),
#     800                                        path.get_transform())
#     801         self._clippath = None
#     802         success = True
#
# File ~/miniconda3/envs/value-agg/lib/python3.11/site-packages/matplotlib/transforms.py:798, in Bbox.unit()
#     795 @staticmethod
#     796 def unit():
#     797     """Create a new unit `Bbox` from (0, 0) to (1, 1)."""
# --> 798     return Bbox([[0, 0], [1, 1]])
#
# File ~/miniconda3/envs/value-agg/lib/python3.11/site-packages/matplotlib/transforms.py:772, in Bbox.__init__(self, points, **kwargs)
#     769     raise ValueError('Bbox points must be of the form '
#     770                      '"[[x0, y0], [x1, y1]]".')
#     771 self._points = points
# --> 772 self._minpos = _default_minpos.copy()
#     773 self._ignore = True
#     774 # it is helpful in some contexts to know if the bbox is a
#     775 # default or has been mutated; we store the orig points to
#     776 # support the mutated methods
#
# KeyboardInterrupt:
