# %% [markdown]
# # Distribution Checker
# This file picks out a random .csv from each society folder, and its distribtion is checked and printed
#
# Columns in each society csv are the following: ,agent_id,pp_1,pp_1_1,pp_2,pp_2_1,pp_3,pp_3_1,P_1,P_1_1,P_2,P_2_1,P_3,P_3_1,a_enjoy_camp,a_enjoy_resort,a_budget_camp,a_budget_resort,a_conform_chain,a_conform_independent,a_stim_chain,a_stim_independent,a_enjoy_classic,a_enjoy_unknown,a_stimulation_classic,a_stimulation_unknown

# %%
import pandas as pd
import matplotlib.pyplot as plt
import random


society_num = random.randint(1,100) 
util_file = pd.read_csv('/home/ia23938/Documents/GitHub/ValueSystemsAggregation/data/society_data/util_societies/util_society_'+str(society_num)+'.csv')

util_file.describe()
# Out:
#        Unnamed: 0    agent_id        pp_1      pp_1_1        pp_2      pp_2_1  \
# count  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# mean    49.500000   49.500000    0.200176    0.799824    0.519227    0.480773
# std     29.011492   29.011492    0.103486    0.103486    0.094940    0.094940
# min      0.000000    0.000000    0.000000    0.550915    0.311713    0.257294
# 25%     24.750000   24.750000    0.132023    0.744165    0.444291    0.417699
# 50%     49.500000   49.500000    0.199231    0.800769    0.517288    0.482712
# 75%     74.250000   74.250000    0.255835    0.867977    0.582301    0.555709
# max     99.000000   99.000000    0.449085    1.000000    0.742706    0.688287
#
#              pp_3      pp_3_1         P_1       P_1_1  ...  a_budget_camp  \
# count  100.000000  100.000000  100.000000  100.000000  ...     100.000000
# mean     0.503864    0.496136    0.500092    0.499908  ...       0.030588
# std      0.099985    0.099985    0.106722    0.106722  ...       0.474404
# min      0.288343    0.248833    0.178100    0.276487  ...      -1.000000
# 25%      0.423974    0.428863    0.432811    0.436926  ...      -0.348380
# 50%      0.512697    0.487303    0.503542    0.496458  ...       0.062926
# 75%      0.571137    0.576026    0.563074    0.567189  ...       0.366602
# max      0.751167    0.711657    0.723513    0.821900  ...       1.000000
#
#        a_budget_resort  a_conform_chain  a_conform_independent  a_stim_chain  \
# count       100.000000       100.000000             100.000000    100.000000
# mean          0.030859        -0.045589              -0.056810      0.043680
# std           0.502894         0.461359               0.485182      0.407180
# min          -1.000000        -1.000000              -1.000000     -1.000000
# 25%          -0.315000        -0.356151              -0.366041     -0.238851
# 50%           0.040660        -0.013394              -0.032229      0.049107
# 75%           0.418871         0.271200               0.249820      0.308970
# max           1.000000         1.000000               1.000000      0.995278
#
#        a_stim_independent  a_enjoy_classic  a_enjoy_unknown  \
# count          100.000000       100.000000       100.000000
# mean            -0.007562        -0.088490        -0.036567
# std              0.457739         0.463299         0.463817
# min             -1.000000        -1.000000        -0.897187
# 25%             -0.291104        -0.396374        -0.371976
# 50%             -0.012554        -0.069985        -0.081843
# 75%              0.344088         0.156164         0.233940
# max              1.000000         1.000000         1.000000
#
#        a_stimulation_classic  a_stimulation_unknown
# count             100.000000             100.000000
# mean               -0.068055               0.033618
# std                 0.449412               0.459298
# min                -1.000000              -1.000000
# 25%                -0.368852              -0.290066
# 50%                -0.010903               0.048021
# 75%                 0.226375               0.367840
# max                 1.000000               1.000000
#
# [8 rows x 26 columns]

# %%
col = "pp_2"

util_file[col].hist()
# add labels and title
plt.xlabel('value')
plt.ylabel('Frequency')
plt.title('Distribution of '+col)
# Out:
# Text(0.5, 1.0, 'Distribution of pp_2')
