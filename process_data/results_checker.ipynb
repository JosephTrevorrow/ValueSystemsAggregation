# %%
import pandas as pd

filename = "/home/ia23938/Documents/GitHub/ValueSystemsAggregation/1-11-results-actions.csv"

results_df = pd.read_csv(filename)

import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
plt.plot(results_df['p'], results_df['Rel_div_p'], label='Rel_div_p')
plt.plot(results_df['p'], results_df['Nonrel_div_p'], label='Nonrel_div_p')
plt.xlabel('p')
plt.ylabel('Value')
plt.legend()
plt.grid(True)
plt.show()
